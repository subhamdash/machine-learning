# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.chdir("E:/Subham/Stastics/titanic")

# %%
ls
# Out:
#  Volume in drive E has no label.
#  Volume Serial Number is 309F-74C9
#
#  Directory of E:\Subham\Stastics\titanic
#
# 04/27/2020  04:38 PM    <DIR>          .
# 04/27/2020  04:38 PM    <DIR>          ..
# 12/11/2019  02:17 AM             3,258 gender_submission.csv
# 12/11/2019  02:17 AM            28,629 test.csv
# 12/11/2019  02:17 AM            61,194 train.csv
#                3 File(s)         93,081 bytes
#                2 Dir(s)  646,499,688,448 bytes free

# %%
train_df=pd.read_csv("train.csv")

# %%
test_df=pd.read_csv("test.csv")

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
train_df_filtered=train_df
train_df_filtered.dropna(axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df_filtered.dropna(how='all',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df_filtered.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df_filtered.fillna(train_df_filtered.mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
train_df_filtered.duplicated().sum()
# Out:
# 0

# %%
train_df_filtered.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

# %%
sns.barplot(x=train_df_filtered.Embarked,y=train_df_filtered.PassengerId)

# %%
train_df_filtered.Age.plot.hist(bins=50)

# %% [markdown]
# # Seven features are integer or floats. Six in case of test train_dfset.
# # Five features are strings (object).

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Names are unique across the train_dfset (count=unique=891)
# Sex variable as two possible values with 65% male (top=male, freq=577/count=891).
# Cabin values have several dupicates across samples. Alternatively several passengers shared a cabin.
# Embarked takes three possible values. S port used by most passengers (top=S)
# Ticket feature has high ratio (22%) of duplicate values (unique=681).

# %%
train_df.describe(include=['O'])
# Out:
#                             Name   Sex  Ticket Cabin Embarked
# count                        891   891     891   204      889
# unique                       891     2     681   147        3
# top     Baxter, Mr. Quigg Edmond  male  347082    G6        S
# freq                           1   577       7     4      644

# %%
dddd=train_df.groupby(['Pclass', 'Survived']).mean()

# %%
dddd
# Out:
#                  PassengerId        Age     SibSp     Parch       Fare
# Pclass Survived
# 1      0          410.300000  43.695312  0.287500  0.300000  64.684008
#        1          491.772059  35.368197  0.492647  0.389706  95.608029
# 2      0          452.123711  33.544444  0.319588  0.144330  19.412328
#        1          439.080460  25.901566  0.494253  0.643678  22.055700
# 3      0          453.580645  26.555556  0.672043  0.384409  13.669364
#        1          394.058824  20.646118  0.436975  0.420168  13.694887

# %%
train_df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# # Pclass We observe significant correlation (>0.5) among Pclass=1 and Survived (classifying #3). We decide to include this feature in our model.

# %%
train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# Sex We confirm the observation during problem definition that Sex=female had very high survival rate at 74% (classifying #1).

# %%
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# # SibSp and Parch These features have zero correlation for certain values. It may be best to derive a feature or a set of features from these individual features (creating #1).
# eg:-Sib Sp-5,8 & parch-4,6

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(train_df, col='Survived')
g.map(plt.hist, 'Age', bins=20)

# %%
train_df['Title'] = train_df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train_df.Title.value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Sir           1
# Countess      1
# Mme           1
# Lady          1
# Capt          1
# Don           1
# Ms            1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
train_df[['Title', 'Survived']].groupby(['Title']).sum()
# Out:
#           Survived
# Title
# Capt             0
# Col              1
# Countess         1
# Don              0
# Dr               3
# Jonkheer         0
# Lady             1
# Major            1
# Master          23
# Miss           127
# Mlle             2
# Mme              1
# Mr              81
# Mrs             99
# Ms               1
# Rev              0
# Sir              1

# %% [markdown]
# # We can see total number of miss are 182 out of which 127 have survived

# %%
pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %% [markdown]
# # Miss,Mr,Mrs contains <75% title and other are rare titles

# %%
train_df['Title'] = train_df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

# %%
train_df['Title'] = train_df['Title'].replace('Mlle', 'Miss')

# %%
train_df['Title'] = train_df['Title'].replace('Ms', 'Miss')
train_df['Title'] = train_df['Title'].replace('Mme', 'Mrs')

# %%
train_df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
pd.crosstab(train_df['Title'], train_df['Sex'])
# Out:
# Sex     female  male
# Title
# Master       0    40
# Miss       185     0
# Mr           0   517
# Mrs        126     0
# Rare         3    20

# %%
train_df[['Title', 'Survived']].groupby(['Title']).sum()
# Out:
#         Survived
# Title
# Master        23
# Miss         130
# Mr            81
# Mrs          100
# Rare           8

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
train_df['Title'] = train_df['Title'].map(title_mapping)

# %%
train_df = train_df.drop(['Name', 'PassengerId'], axis=1)

# %%
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    0  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1       1    1  38.0      1      0          PC 17599  71.2833   C85
# 2         1       3    1  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    1  35.0      1      0            113803  53.1000  C123
# 4         0       3    0  35.0      0      0            373450   8.0500   NaN
#
#   Embarked  Title
# 0        S      1
# 1        C      3
# 2        S      2
# 3        S      3
# 4        S      1

# %%
train_df['Sex'] = train_df['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %% [markdown]
# # Here we want to calculate family size by adding SibSp(sibbling and spouse) and Parch(Parent and Childeren)

# %%
train_df['FamilySize']=train_df['SibSp']+train_df['Parch'] +1

# %%
train_df[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean()
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %%
train_df['IsAlone'] = 0

# %%
train_df.loc[train_df['FamilySize'] == 1, 'IsAlone'] = 1

# %%
train_df[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %% [markdown]
# # We are determining whether the person is alone or with family

# %%
train_df = train_df.drop(['SibSp', 'Parch','FamilySize'], axis=1)

# %%
train_df.Embarked.isnull().sum()
# Out:
# 2

# %% [markdown]
# # There are two coloumns of embarked where it is null so we are filling these values with most occuring values in the dataset

# %%
freq_port = train_df.Embarked.dropna().mode()[0]

# %%
train_df['Embarked'] = train_df['Embarked'].fillna(freq_port)

# %%
train_df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %% [markdown]
# # Age TICKET FARE and CABIN are values we need to look up for.But Ticket cannot give any information about survival and cabin column has more than 80% of null data so we will delete this two feature

# %%
train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)

# %%
test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True) #filling null value with the median

# %%
train_df['FareBand'] = pd.qcut(train_df['Fare'], 4)
train_df[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
train_df.loc[train_df['Fare'] <= 7.91, 'Fare'] = 0
train_df.loc[(train_df['Fare'] > 7.91) & (train_df['Fare'] <= 14.454), 'Fare'] = 1
train_df.loc[(train_df['Fare'] > 14.454) & (train_df['Fare'] <= 32), 'Fare'] = 2
train_df.loc[train_df['Fare'] > 31, 'Fare']  = 3
train_df['Fare'] = train_df['Fare'].astype(int)

# %%
train_df = train_df.drop(['FareBand'], axis=1)

# %%
 train_df['Embarked'] = train_df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# %%
train_df
# Out:
#      Survived  Pclass  Sex   Age  Fare  Embarked  Title  IsAlone
# 0           0       3    0  22.0     0         0      1        0
# 1           1       1    1  38.0     3         1      3        0
# 2           1       3    1  26.0     1         0      2        1
# 3           1       1    1  35.0     3         0      3        0
# 4           0       3    0  35.0     1         0      1        1
# ..        ...     ...  ...   ...   ...       ...    ...      ...
# 886         0       2    0  27.0     1         0      5        1
# 887         1       1    1  19.0     2         0      2        1
# 888         0       3    1   NaN     2         0      2        0
# 889         1       1    0  26.0     2         1      1        1
# 890         0       3    0  32.0     0         2      1        1
#
# [891 rows x 8 columns]

# %% [markdown]
# # We have dealt with all the features excpet the Age So we will fill find a way to fill the Age Column with null value

# %%
age_avg = train_df['Age'].mean()
age_std = train_df['Age'].std()
age_null_count = train_df['Age'].isnull().sum()

# %%
age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)

# %%
train_df['Age'][np.isnan(train_df['Age'])] = age_null_random_list
# Out:
# C:\Users\GSD\Anaconda3\envs\tensorflow_cpu\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-271-558ae55d37b8> in <module>
# ----> 1 train_df['Age'][np.isnan(train_df['Age'])] = age_null_random_list
#       2 train_df['Age'] = train_df['Age'].astype(int)
#
# ~\Anaconda3\envs\tensorflow_cpu\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#    1242         # do the setitem
#    1243         cacher_needs_updating = self._check_is_chained_assignment_possible()
# -> 1244         setitem(key, value)
# ...

# %%
train_df['Age'] = train_df['Age'].astype(int)

# %%
train_df['CategoricalAge'] = pd.cut(train_df['Age'], 5)

# %%
train_df[['CategoricalAge', 'Survived']].groupby(['CategoricalAge'], as_index=False).mean().sort_values(by='CategoricalAge', ascending=True)
# Out:
#   CategoricalAge  Survived
# 0  (-0.08, 16.0]  0.500000
# 1   (16.0, 32.0]  0.344828
# 2   (32.0, 48.0]  0.403433
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
train_df.loc[train_df['Age'] <= 16, 'Age'] = 0
train_df.loc[(train_df['Age'] > 16) & (train_df['Age'] <= 32), 'Age'] = 1
train_df.loc[(train_df['Age'] > 32) & (train_df['Age'] <= 48), 'Age'] = 2
train_df.loc[(train_df['Age'] > 48) & (train_df['Age'] <= 64), 'Age'] = 3
train_df.loc[train_df['Age'] > 64, 'Age']  = 4
train_df['Age'] = train_df['Age'].astype(int)

# %%
train_df=train_df.drop(['CategoricalAge'], axis=1)

# %% [markdown]
# # Our dat is finally ready

# %%
train_df
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone
# 0           0       3    0    1     0         0      1        0
# 1           1       1    1    2     3         1      3        0
# 2           1       3    1    1     1         0      2        1
# 3           1       1    1    2     3         0      3        0
# 4           0       3    0    2     1         0      1        1
# ..        ...     ...  ...  ...   ...       ...    ...      ...
# 886         0       2    0    1     1         0      5        1
# 887         1       1    1    1     2         0      2        1
# 888         0       3    1    2     2         0      2        0
# 889         1       1    0    1     2         1      1        1
# 890         0       3    0    1     0         2      1        1
#
# [891 rows x 8 columns]
